# %%
import sys

sys.path.append(
    '/data/groups/jeltema/zhou/lsst_shear/WeakLensingDeblending/bin')
sys.path.append('/data/groups/jeltema/zhou/lsst_shear/WeakLensingDeblending')

import numpy as np
from astropy.io import fits
from astropy.table import Table
import pickle
from tqdm import tqdm

from gals_wideblend import init_wldeblend, get_gal_wldeblend


def get_gal():
    dc2_path = "../data/dc2_table.fits"
    dc2 = Table(fits.open(dc2_path)[1].data)
    dc2_df = dc2.to_pandas()

    # dc2_df = dc2_df.loc[0:1000]

    data = init_wldeblend(survey_bands='lsst-i',
                          catalog_path="../data/dc2_table.fits")

    gal_list = []

    i = 0
    for index, gal in tqdm(dc2_df.iterrows()):
        wl_gal = get_gal_wldeblend(rng=np.random.RandomState(1234),
                                   ind=i,
                                   data=data)
        # with open("../data/gals/gals_{}.pkl".format(gal.name), "wb") as f:
        # pickle.dump(wl_gal, f)
        i += 1
        gal_list.append(wl_gal)

    return gal_list

    # with open("../data/dc2_gals_wl.pkl", "wb") as f:
        # pickle.dump(gal_list, f)

    # dc2_df['wf_gal'] = gal_list
    # dc2_df.to_pickle("../data/dc2_gals_wl.pkl")
    # df.to_hdf('data.h5', key='df', mode='w')
    # dc2_df.to_hdf("../data/dc2_gals_wl.h5", key='dc2', mode='w')

# %%
gal_list = get_gal()
# Out:
# 10481295it [1:25:06, 2052.60it/s]

# %%
dc2_path = "../data/dc2_table.fits"
dc2 = Table(fits.open(dc2_path)[1].data)
dc2_df = dc2.to_pandas()

# %%
dc2_df['wf_gal'] = gal_list

# %%
dc2_df.to_pickle("../data/dc2_gals_wl.pkl")

# %%
import pandas as pd
test = pd.read_pickle("../data/dc2_gals_wl.pkl")
# Out:
#                  ra        dec       g_ab       r_ab       i_ab       z_ab  \
# 0         62.584977 -40.334110  16.389235  15.969118  15.751877  15.644171
# 1         61.398620 -41.036142  19.776192  19.318966  19.032682  18.882126
# 2         61.024250 -39.783545  17.942350  17.240576  16.882887  16.658743
# 3         61.420014 -39.964448  18.457945  17.741489  17.340651  16.984100
# 4         61.869596 -40.907121  14.888106  14.139737  13.786592  13.539910
# ...             ...        ...        ...        ...        ...        ...
# 10481290  66.491210 -38.755338  26.147915  25.837452  25.906286  25.985991
# 10481291  66.537279 -38.458811  26.022764  25.713081  25.772373  25.819675
# 10481292  65.459549 -38.750976  26.357021  25.871912  26.018427  26.340965
# 10481293  66.490990 -38.819750  25.691710  25.463957  25.543995  25.613464
# 10481294  65.725766 -39.668859  26.523649  25.994267  26.018976  26.081064
#
#           fluxnorm_bulge  fluxnorm_disk  fluxnorm_agn     pa_disk  ...  \
# 0               0.322700       0.677300           0.0  -66.420097  ...
# 1               0.070049       0.929951           0.0  -59.928261  ...
# 2               0.166495       0.833505           0.0  -26.887655  ...
# 3               0.331346       0.668654           0.0  -87.747124  ...
# 4               0.992869       0.007131           0.0  -94.425529  ...
# ...                  ...            ...           ...         ...  ...
# 10481290        0.902513       0.097487           0.0  -58.620407  ...
# 10481291        0.999387       0.000613           0.0  -68.361343  ...
# 10481292        0.020686       0.979314           0.0  -88.874046  ...
# 10481293        0.991288       0.008712           0.0 -138.421860  ...
# 10481294        0.968438       0.031562           0.0 -110.837479  ...
#
#           redshift   galtileid     halo_mass         halo_id  stellar_mass  \
# 0         0.022012  9687500000  2.472611e+11          155487  2.266592e+09
# 1         0.020724  9687500001  5.465768e+10       100155487  2.167333e+07
# 2         0.020339  9687500002  1.197264e+11       200155487  2.931496e+08
# 3         0.018407  9687500003  7.027417e+10       300155487  1.110973e+08
# 4         0.021334  9687500004  1.206931e+13       400155487  2.895573e+10
# ...            ...         ...           ...             ...           ...
# 10481290  2.998345  8958249412  1.931316e+11 -57201100143121  7.431215e+08
# 10481291  3.035001  8958255826  1.837721e+11 -57842500143121  6.610531e+08
# 10481292  2.993862  8958269275  3.047939e+11 -59187400143121  1.815956e+09
# 10481293  2.996018  8958269333  2.054912e+11 -59193200143121  6.657295e+08
# 10481294  3.032598  8958283145  3.297796e+11 -60574400143121  2.305365e+09
#
#           is_central   position_x   position_y   position_z  \
# 0               True    31.803397    61.315617   -58.648784
# 1               True    31.841531    58.398153   -57.894194
# 2               True    32.094391    57.957652   -55.165675
# 3               True    27.632383    50.723524   -48.406853
# 4               True    31.566351    59.043094   -58.009892
# ...              ...          ...          ...          ...
# 10481290        True  2020.564034  4646.644614 -4068.034771
# 10481291        True  2036.108398  4693.232491 -4064.598922
# 10481292        True  2102.848193  4605.371781 -4064.488199
# 10481293        True  2017.418230  4639.225146 -4070.863020
# 10481294        True  2065.371231  4580.922301 -4167.499725
#
#                                                      wf_gal
# 0         ([(galsim.Exponential(scale_radius=2.160357360...
# 1         ([(galsim.Exponential(scale_radius=0.837810379...
# 2         ([(galsim.Exponential(scale_radius=1.728351182...
# 3         ([(galsim.Exponential(scale_radius=2.053063370...
# 4         ([(galsim.Exponential(scale_radius=5.167037971...
# ...                                                     ...
# 10481290  ([(galsim.Exponential(scale_radius=0.115381143...
# 10481291  ([(galsim.Exponential(scale_radius=0.195102039...
# 10481292  ([(galsim.Exponential(scale_radius=0.101492000...
# 10481293  ([(galsim.Exponential(scale_radius=0.082384586...
# 10481294  ([(galsim.Exponential(scale_radius=0.073250506...
#
# [10481295 rows x 25 columns]
